# %%
#importing libraries

# %%
import pandas as pd #csv i/o

# %%
df=pd.io.parsers.read_csv('Data sets/kc_house_data.csv', dtype={'zipcode': 'str'})

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.shape[0]
# Out:
# 21613

# %%
#There are no missing values in the dataset, So there is no need for any missing value treatment.

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
#assigning datetime format to date column

# %%
df['date'].iloc[:10]
# Out:
# 0   2014-10-13
# 1   2014-12-09
# 2   2015-02-25
# 3   2014-12-09
# 4   2015-02-18
# 5   2014-05-12
# 6   2014-06-27
# 7   2015-01-15
# 8   2015-04-15
# 9   2015-03-12
# Name: date, dtype: datetime64[ns]

# %%
df['date'].iloc[-10:]
# Out:
# 21603   2014-08-25
# 21604   2015-01-26
# 21605   2014-10-14
# 21606   2015-03-26
# 21607   2015-02-19
# 21608   2014-05-21
# 21609   2015-02-23
# 21610   2014-06-23
# 21611   2015-01-16
# 21612   2014-10-15
# Name: date, dtype: datetime64[ns]

# %%
df.plot('date', 'price')

# %%
#There is no pattern in the date and price the pattern may be noticed in the data with large date range.

# %%
#Dropping the ID and Date variable from the dataframe

# %%
df.drop(['id', 'date', 'zipcode'], axis= 1, inplace= True)

# %%
df.iloc[:10]
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   221900.0         3       1.00         1180      5650     1.0           0
# 1   538000.0         3       2.25         2570      7242     2.0           0
# 2   180000.0         2       1.00          770     10000     1.0           0
# 3   604000.0         4       3.00         1960      5000     1.0           0
# 4   510000.0         3       2.00         1680      8080     1.0           0
# 5  1225000.0         4       4.50         5420    101930     1.0           0
# 6   257500.0         3       2.25         1715      6819     2.0           0
# 7   291850.0         3       1.50         1060      9711     1.0           0
# 8   229500.0         3       1.00         1780      7470     1.0           0
# 9   323000.0         3       2.50         1890      6560     2.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
#importing remaining libraries

# %%
import numpy as np #linear algebra
import seaborn as sns #visualisation lib. box plot, scatter, etc.
import matplotlib
import matplotlib.pyplot as plt #Visualisation
# %matplotlib inline

# %%
df.isnull().any()
# Out:
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront       False
# view             False
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated     False
# lat              False
# long             False
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#There are no missing values

# %%
df['yr_renovated'].unique()
# Out:
# array([   0, 1991, 2002, 2010, 1999, 1992, 2013, 1994, 1978, 2005, 2008,
#        2003, 1984, 1954, 2014, 2011, 1974, 1983, 1945, 1990, 1988, 1957,
#        1977, 1981, 1995, 2000, 1998, 1970, 1989, 2004, 1986, 2009, 2007,
#        1987, 1973, 2006, 1985, 2001, 1980, 1971, 1979, 1997, 1950, 1969,
#        1948, 2015, 1968, 2012, 1963, 1951, 1993, 1962, 1996, 1972, 1953,
#        1955, 1982, 1956, 1940, 1976, 1946, 1975, 1958, 1964, 1959, 1960,
#        1967, 1965, 1934, 1944], dtype=int64)

# %%
sns.pairplot(df, x_vars=['bedrooms', 'bathrooms', 'floors', 'condition', 'grade'], y_vars=['price'], height=5, aspect=0.7, kind= 'scatter')

# %%
df1=df[['price', 'bedrooms', 'bathrooms', 'sqft_living',
    'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
    'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
    'lat', 'long', 'sqft_living15', 'sqft_lot15']]
h = df1.hist(bins=25,figsize=(16,16),xlabelsize='10',ylabelsize='10',xrot=-15)
sns.despine(left=True, bottom=True)
[x.title.set_size(12) for x in h.ravel()];
[x.yaxis.tick_left() for x in h.ravel()];

# %%
sns.boxplot(x=df['bedrooms'],y=df['price'])

# %%
#We can see some outliers like houses with 33 bedrooms and prices over 7000000,
    #but in real datas we will need to work datas like this with luxury houses so we will not drop the outliers here.

# %%
sns.boxplot(x=df['floors'],y=df['price'])

# %%
#Same case as Bedrooms

# %%
sns.boxplot(x=df['waterfront'], y=df['price'])

# %%
#We can see that Houses with Waterfront have higher prices compared to houses without a waterfront

# %%
sns.boxplot(x=df['view'], y=df['price'])

# %%
#Boxplot visualisation shows that houses with better gets better price.

# %%
sns.boxplot(x=df['grade'], y=df['price'])

# %%
#As the grade increases the price of houses increase strong relation between that can be noticed

# %%
sns.boxplot(x=df['condition'], y=df['price'])

# %%
#The condition of the houses doesn't effect the price too much after rating higher than 3, but for rating less than 3 effects can be seen.

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
features=['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
       'waterfront', 'view', 'condition', 'grade', 'sqft_above',
       'sqft_basement', 'yr_built', 'yr_renovated', 'lat', 'long',
       'sqft_living15', 'sqft_lot15']

# %%
mask = np.zeros_like(df[features].corr(), dtype=np.bool) 
mask[np.triu_indices_from(mask)] = True 

f, ax = plt.subplots(figsize=(16, 12))
plt.title('Pearson Correlation Matrix',fontsize=25)

sns.heatmap(df[features].corr(),linewidths=0.25,vmax=0.7,square=True,cmap="BuGn", #"BuGn_r" to reverse 
            linecolor='w',annot=True,annot_kws={"size":8},mask=mask,cbar_kws={"shrink": .9});

# %%
plt.figure(figsize= (16,12))
sns.heatmap(df[features].corr(), annot=True)

# %%
#From the pearson correlation map we notice that sqft_living, grade, and sqft_above has the highest effect on the house price

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn import metrics

# %%
#Importing libraaries for linear regression model

# %%
X= df[['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
       'waterfront', 'view', 'condition', 'grade', 'sqft_above',
       'sqft_basement', 'yr_built', 'yr_renovated', 'lat', 'long',
       'sqft_living15', 'sqft_lot15']]
#Independent Variables

# %%
y= df['price']
#Dependent Variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7 , random_state=100)
# Out:
# C:\Users\Prometheus\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
lm=linear_model.LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
coeff_df = pd.DataFrame(lm.coef_,X_test.columns,columns=['Coefficient'])
coeff_df
# Out:
#                  Coefficient
# bedrooms       -32798.908722
# bathrooms       48112.513771
# sqft_living       102.684289
# sqft_lot            0.120084
# floors           2716.357154
# waterfront     642901.781727
# view            43716.579677
# condition       32337.662463
# grade          100299.599374
# sqft_above         64.996269
# sqft_basement      37.688020
# yr_built        -2587.903947
# yr_renovated       11.029445
# lat            560418.706468
# long          -107181.506316
# sqft_living15      30.473282
# sqft_lot15         -0.340465

# %%
#If the house is located with water front or not has the highest effect on it's price. While size of the parking lot has least impact on the House price.

# %%
y_pred = lm.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r_squared = r2_score(y_test, y_pred)

# %%
from math import sqrt
rmse = sqrt(mse)

# %%
#defining formulas

# %%
print('Mean_Squared_Error :' ,mse)
print('Root_Mean_Squared_Error :' ,rmse)
print('r_square_value :',r_squared)
# Out:
# Mean_Squared_Error : 42997414822.21811
# Root_Mean_Squared_Error : 207358.18002243873
# r_square_value : 0.6829169639532927

# %%
import statsmodels.api as sm
X_train_sm = X_train
X_train_sm = sm.add_constant(X_train_sm)
lm_1 = sm.OLS(y_train,X_train_sm).fit()
lm_1.params
# Out:
# C:\Users\Prometheus\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# const           -3.540022e+07
# bedrooms        -3.279891e+04
# bathrooms        4.811251e+04
# sqft_living      1.026842e+02
# sqft_lot         1.200836e-01
# floors           2.716357e+03
# waterfront       6.429018e+05
# view             4.371658e+04
# condition        3.233766e+04
# grade            1.002996e+05
# sqft_above       6.499631e+01
# sqft_basement    3.768806e+01
# yr_built        -2.587904e+03
# yr_renovated     1.102945e+01
# lat              5.604187e+05
# long            -1.071815e+05
# sqft_living15    3.047328e+01
# sqft_lot15      -3.404646e-01
# dtype: float64

# %%
print(lm_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.700
# Method:                 Least Squares   F-statistic:                     2205.
# Date:                Fri, 12 Jul 2019   Prob (F-statistic):               0.00
# Time:                        22:34:49   Log-Likelihood:            -2.0619e+05
# No. Observations:               15129   AIC:                         4.124e+05
# Df Residuals:                   15112   BIC:                         4.125e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          -3.54e+07   1.88e+06    -18.831      0.000   -3.91e+07   -3.17e+07
# ...
